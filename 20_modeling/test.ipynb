# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

test = pd.read_csv("/Users/yangshining/Desktop/2021 fall @duke/IDS 720/mid-sem project/data/arcos-fl-statewide-itemized.csv", nrows=500)

test
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-aa130da732e0> in <module>
#       1 pd.set_option('display.max_columns', None)
#       2
# ----> 3 test = pd.read_csv("/Users/yangshining/Desktop/2021 fall @duke/IDS 720/mid-sem project/data/arcos-fl-statewide-itemized.csv", nrows=500)
#       4
#       5 test
#
# ...

# %%
'''raw_data = pd.read_csv("/Users/yangshining/Desktop/2021 fall @duke/IDS 720/mid-sem project/data/arcos-fl-statewide-itemized.csv", iterator= True, chunksize = 10000)

select_data=[]

for df in raw_data:
    #df = df[(df["id"]== "AG000060390") | (df["id"]== "USC00050848")]
    select_data.append(df)


my_data = pd.concat(select_data)'''

# %% [markdown]
# ## mortality data

# %%
pd.set_option('display.max_rows', None)

death2003 = pd.read_csv("/Users/yangshining/Desktop/2021 fall @duke/IDS 720/mid-sem project/data/US_VitalStatistics/Underlying Cause of Death, 2003.txt", sep= '\t')

test2003 = death2003.copy()

#test2003["Drug/Alcohol Induced Cause"].value_counts()

test2003.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4055aa18d70a> in <module>
# ----> 1 pd.set_option('display.max_rows', None)
#       2
#       3 death2003 = pd.read_csv("/Users/yangshining/Desktop/2021 fall @duke/IDS 720/mid-sem project/data/US_VitalStatistics/Underlying Cause of Death, 2003.txt", sep= '\t')
#       4
#       5 test2003 = death2003.copy()
#
# NameError: name 'pd' is not defined

# %%
test2003[["County Code", "Year", "Year Code"]] = test2003[["County Code", "Year", "Year Code"]].fillna(0.0).astype(int)

len(test2003["County"].unique())

# %%
test2003[test2003["County"].isnull()]
# Out:
#                                                   Notes County  County Code  \
# 4087                                                ---    NaN            0
# 4088      Dataset: Underlying Cause of Death, 1999-2017    NaN            0
# 4089                                  Query Parameters:    NaN            0
# 4090  Group By: County; Year; Drug/Alcohol Induced C...    NaN            0
# 4091                              Show Totals: Disabled    NaN            0
# 4092                         Show Zero Values: Disabled    NaN            0
# 4093                             Show Suppressed: False    NaN            0
# 4094                                                ---    NaN            0
# 4095  Help: See http://wonder.cdc.gov/wonder/help/uc...    NaN            0
# 4096                                                ---    NaN            0
# 4097  Suggested Citation: Centers for Disease Contro...    NaN            0
# ...

# %% [markdown]
# ## FIPS code

# %%
fips = pd.read_csv("https://raw.githubusercontent.com/kjhealy/fips-codes/master/county_fips_master.csv", encoding="ISO-8859-1")

fips
# Out:
#        fips        county_name state_abbr state_name             long_name  \
# 0      1001     Autauga County         AL    Alabama     Autauga County AL
# 1      1003     Baldwin County         AL    Alabama     Baldwin County AL
# 2      1005     Barbour County         AL    Alabama     Barbour County AL
# 3      1007        Bibb County         AL    Alabama        Bibb County AL
# 4      1009      Blount County         AL    Alabama      Blount County AL
# ...     ...                ...        ...        ...                   ...
# 3141  56037  Sweetwater County         WY    Wyoming  Sweetwater County WY
# 3142  56039       Teton County         WY    Wyoming       Teton County WY
# 3143  56041       Uinta County         WY    Wyoming       Uinta County WY
# 3144  56043    Washakie County         WY    Wyoming    Washakie County WY
# 3145  56045      Weston County         WY    Wyoming      Weston County WY
#
# ...
