# %%
import pandas as pd
import numpy as np

# %%
# Read data 

# opioid
opioid = pd.read_parquet("/Users/yangshining/Desktop/pds2021-opioids-pds6/10_modified_data/opi_merge_final.parquet", engine='fastparquet')

# vital deaths
vital = pd.read_parquet("/Users/yangshining/Desktop/pds2021-opioids-pds6/10_modified_data/Vital.parquet", engine='fastparquet')

# population
population = pd.read_parquet("/Users/yangshining/Desktop/pds2021-opioids-pds6/10_modified_data/pop_final.parquet", engine='fastparquet')

# %%
# Check for number of rows in each dataset

len_opi = len(opioid)
len_vital = len(vital)
len_pop = len(population)

print(f"Opioid dataset has {len_opi} rows; vital deaths dataset has {len_vital} rows; population dataset has {len_pop} rows.")
# Out:
# Opioid dataset has 8736 rows; vital deaths dataset has 7925 rows; population dataset has 31910 rows.

# %%
vital
# Out:
#                  County  County Code  Year  Deaths
# 0     Acadia Parish, LA        22001  2003      11
# 1     Acadia Parish, LA        22001  2005      23
# 2     Acadia Parish, LA        22001  2006      19
# 3     Acadia Parish, LA        22001  2007      19
# 4     Acadia Parish, LA        22001  2009      11
# ...                 ...          ...   ...     ...
# 7920    Yuma County, AZ         4027  2011      20
# 7921    Yuma County, AZ         4027  2012      32
# 7922    Yuma County, AZ         4027  2013      22
# 7923    Yuma County, AZ         4027  2014      35
# 7924    Yuma County, AZ         4027  2015      24
#
# [7925 rows x 4 columns]

# %%
population.sample(10)
# Out:
#        STATE  COUNTY         STNAME          CTYNAME  Year  Population STATE1  \
# 18661     48     283          Texas  La Salle County  2011        7002     48
# 31627     51      89       Virginia     Henry County  2015       51940     51
# 733       18      43        Indiana     Floyd County  2006       72358     18
# 11298     31      89       Nebraska      Holt County  2009       10406     31
# 22547      6      43     California  Mariposa County  2013       17809     06
# 28904      5     145       Arkansas     White County  2015       78915     05
# 22212     54      55  West Virginia    Mercer County  2012       62419     54
# 1520      29      25       Missouri  Caldwell County  2006        9343     29
# 28874      5      85       Arkansas    Lonoke County  2015       71359     05
# 13433     17     121       Illinois    Marion County  2010       39437     17
#
#       COUNTY1   FIPS
# 18661     283  48283
# 31627     089  51089
# 733       043  18043
# 11298     089  31089
# 22547     043  06043
# 28904     145  05145
# 22212     055  54055
# 1520      025  29025
# 28874     085  05085
# 13433     121  17121

# %% [markdown]
# ## Merge opioid dataset with population

# %%
# Modify data types of columns - prepare for merging

population["Year"] = population["Year"].astype(int)

opioid["fips"] = opioid["fips"].astype(str)

opioid["fips"] = opioid["fips"].apply(lambda x: x.zfill(5))

merge1 = pd.merge(opioid, population, left_on=["fips", "year"], right_on=["FIPS", "Year"], how='left') #Merging based on opioid dataset

# Check if there's any missing value in population

merge1[merge1["Population"].isnull()]  # La Salle is NOT considered to be a county in Louisiana
# Out:
#      county_name state_abbr   fips BUYER_STATE BUYER_COUNTY  year  \
# 3171    LA SALLE         LA  22059          LA     LA SALLE  2006
# 3172    LA SALLE         LA  22059          LA     LA SALLE  2007
# 3173    LA SALLE         LA  22059          LA     LA SALLE  2008
# 3174    LA SALLE         LA  22059          LA     LA SALLE  2009
# 3175    LA SALLE         LA  22059          LA     LA SALLE  2010
# 3176    LA SALLE         LA  22059          LA     LA SALLE  2011
# 3177    LA SALLE         LA  22059          LA     LA SALLE  2012
# 3178    LA SALLE         LA  22059          LA     LA SALLE  2013
# 3179    LA SALLE         LA  22059          LA     LA SALLE  2014
#
#                MME  STATE  COUNTY STNAME CTYNAME  Year  Population STATE1  \
# 3171  3.570544e+06    NaN     NaN    NaN     NaN   NaN         NaN    NaN
# 3172  4.503112e+06    NaN     NaN    NaN     NaN   NaN         NaN    NaN
# 3173  4.978754e+06    NaN     NaN    NaN     NaN   NaN         NaN    NaN
# 3174  5.705937e+06    NaN     NaN    NaN     NaN   NaN         NaN    NaN
# 3175  6.206684e+06    NaN     NaN    NaN     NaN   NaN         NaN    NaN
# 3176  6.813357e+06    NaN     NaN    NaN     NaN   NaN         NaN    NaN
# 3177  7.597359e+06    NaN     NaN    NaN     NaN   NaN         NaN    NaN
# 3178  7.459239e+06    NaN     NaN    NaN     NaN   NaN         NaN    NaN
# 3179  8.371265e+06    NaN     NaN    NaN     NaN   NaN         NaN    NaN
#
#      COUNTY1 FIPS
# 3171     NaN  NaN
# 3172     NaN  NaN
# 3173     NaN  NaN
# 3174     NaN  NaN
# 3175     NaN  NaN
# 3176     NaN  NaN
# 3177     NaN  NaN
# 3178     NaN  NaN
# 3179     NaN  NaN

# %% [markdown]
# ## Generate MME per cap

# %%
merge1["MME per cap"] = merge1["MME"]/merge1["Population"]

# Store data in parquet

merge1.to_parquet("/Users/yangshining/Desktop/plotting_test/merge1.parquet", engine='fastparquet')

# %% [markdown]
# ## Merge vital deaths dataset with population

# %%
vital
# Out:
#                  County County Code  Year  Deaths
# 0     Acadia Parish, LA       22001  2003      11
# 1     Acadia Parish, LA       22001  2005      23
# 2     Acadia Parish, LA       22001  2006      19
# 3     Acadia Parish, LA       22001  2007      19
# 4     Acadia Parish, LA       22001  2009      11
# ...                 ...         ...   ...     ...
# 7920    Yuma County, AZ       04027  2011      20
# 7921    Yuma County, AZ       04027  2012      32
# 7922    Yuma County, AZ       04027  2013      22
# 7923    Yuma County, AZ       04027  2014      35
# 7924    Yuma County, AZ       04027  2015      24
#
# [7925 rows x 4 columns]

# %%
population["Year"].value_counts()
# Out:
# 2006    3191
# 2007    3191
# 2008    3191
# 2009    3191
# 2010    3191
# 2011    3191
# 2012    3191
# 2013    3191
# 2014    3191
# 2015    3191
# Name: Year, dtype: int64

# %%
vital["County Code"] = vital["County Code"].astype(str)
vital["County Code"] = vital["County Code"].apply(lambda x: x.zfill(5))

#vital[vital["County Code"] == "18043"]

merge2= pd.merge(vital, population, left_on=["County Code", "Year"], right_on=["FIPS", "Year"], how='left') #Merging based on vital deaths dataset

merge2[merge2["Population"].isnull()]
# Out:
#                  County County Code  Year  Deaths  STATE  COUNTY STNAME  \
# 0     Acadia Parish, LA       22001  2003      11    NaN     NaN    NaN
# 1     Acadia Parish, LA       22001  2005      23    NaN     NaN    NaN
# 7        Ada County, ID       16001  2003      17    NaN     NaN    NaN
# 8        Ada County, ID       16001  2004      21    NaN     NaN    NaN
# 9        Ada County, ID       16001  2005      20    NaN     NaN    NaN
# ...                 ...         ...   ...     ...    ...     ...    ...
# 7901    York County, PA       42133  2005      33    NaN     NaN    NaN
# 7912    York County, SC       45091  2003      10    NaN     NaN    NaN
# 7913    York County, SC       45091  2004      11    NaN     NaN    NaN
# 7914    York County, SC       45091  2005      23    NaN     NaN    NaN
# 7925    Yuma County, AZ       04027  2005      14    NaN     NaN    NaN
#
#      CTYNAME  Population STATE1 COUNTY1 FIPS
# 0        NaN         NaN    NaN     NaN  NaN
# 1        NaN         NaN    NaN     NaN  NaN
# 7        NaN         NaN    NaN     NaN  NaN
# 8        NaN         NaN    NaN     NaN  NaN
# 9        NaN         NaN    NaN     NaN  NaN
# ...      ...         ...    ...     ...  ...
# 7901     NaN         NaN    NaN     NaN  NaN
# 7912     NaN         NaN    NaN     NaN  NaN
# 7913     NaN         NaN    NaN     NaN  NaN
# 7914     NaN         NaN    NaN     NaN  NaN
# 7925     NaN         NaN    NaN     NaN  NaN
#
# [1348 rows x 12 columns]

# %% [markdown]
# ## Generate vital deaths per cap

# %%
merge2["vital deaths per cap"] = merge2["Deaths"]/ merge2["Population"]
