# %%
# Load packages
import pandas as pd
import numpy as np
import fastparquet

# %%
# Don't run this!!!
pop_data = pd.read_csv("/Users/preetkhowaja/Documents/MIDS Fall 2021/Practicing DS/Mid-sem Project/pop_data.csv", encoding='latin-1')
 # drop columns that aren't relevant
pop_data = pop_data.drop(columns = ["SUMLEV", "REGION", "DIVISION", "ESTIMATESBASE2000", "POPESTIMATE2000", 
"POPESTIMATE2001", "POPESTIMATE2002", "POPESTIMATE2003", "POPESTIMATE2004", "POPESTIMATE2005", "POPESTIMATE2010"])
pop_data.head()
# Out:
#    STATE  COUNTY   STNAME         CTYNAME  POPESTIMATE2006  POPESTIMATE2007  \
# 0      1       0  Alabama         Alabama          4628981          4672840
# 1      1       1  Alabama  Autauga County            51328            52405
# 2      1       3  Alabama  Baldwin County           168121           172404
# 3      1       5  Alabama  Barbour County            27861            27757
# 4      1       7  Alabama     Bibb County            22099            22438
#
#    POPESTIMATE2008  POPESTIMATE2009  CENSUS2010POP
# 0          4718206          4757938        4779736
# 1            53277            54135          54571
# 2           175827           179406         182265
# 3            27808            27657          27457
# 4            22705            22941          22915

# %%
# Don't run this!!!
# Reading in pop data after 2010
pop_data_2 = pd.read_csv("/Users/preetkhowaja/Documents/MIDS Fall 2021/Practicing DS/Mid-sem Project/pop_data_2.csv", encoding='latin-1')
pop_data_2 = pop_data_2[["STNAME", "CTYNAME", "POPESTIMATE2011", "POPESTIMATE2012", "POPESTIMATE2013", "POPESTIMATE2014", "POPESTIMATE2015"]]

pop_data_2.head()
# Out:
#     STNAME         CTYNAME  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0  Alabama         Alabama          4799069          4815588          4830081
# 1  Alabama  Autauga County            55227            54954            54727
# 2  Alabama  Baldwin County           186558           190145           194885
# 3  Alabama  Barbour County            27341            27169            26937
# 4  Alabama     Bibb County            22745            22667            22521
#
#    POPESTIMATE2014  POPESTIMATE2015
# 0          4841799          4852347
# 1            54893            54864
# 2           199183           202939
# 3            26755            26283
# 4            22553            22566

# %%
# Don't run this!!!
# Merging both datasets to have complete pop data

pop_merged = pd.merge(left = pop_data, right = pop_data_2)

# %%
# Don't run this!!!
# save file as parquet
pop_merged.to_parquet("/Users/preetkhowaja/Documents/MIDS Fall 2021/Practicing DS/pds2021-opioids-pds6/10_modified_data/pop_final.parquet", 
engine = 'fastparquet')

# %%
# RUN FROM HERE
# Read in parquet data
population = pd.read_parquet("/Users/preetkhowaja/Documents/MIDS Fall 2021/Practicing DS/pds2021-opioids-pds6/10_modified_data/pop_final.parquet", engine = 'fastparquet')

# %%
population.sample(15)
# Out:
#        STATE  COUNTY         STNAME            CTYNAME  POPESTIMATE2006  \
# index
# 2674      48     219          Texas     Hockley County            22912
# 978       20     147         Kansas    Phillips County             5573
# 2048      38      49   North Dakota     McHenry County             5507
# 186        5     147       Arkansas    Woodruff County             7877
# 422       13      51        Georgia     Chatham County           246896
# 1251      25      27  Massachusetts   Worcester County           785345
# 3177      56      19        Wyoming     Johnson County             7796
# 16         1      31        Alabama      Coffee County            46228
# 650       17      83       Illinois      Jersey County            22736
# 2794      48     459          Texas      Upshur County            38004
# 1269      26      33       Michigan    Chippewa County            39051
# 2465      46     129   South Dakota    Walworth County             5469
# 2598      48      67          Texas        Cass County            30095
# 618       17      19       Illinois   Champaign County           193844
# 3069      54      61  West Virginia  Monongalia County            89656
#
#        POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  CENSUS2010POP  \
# index
# 2674             22844            22958            23086          22935
# 978               5588             5586             5620           5642
# 2048              5370             5355             5373           5395
# 186               7648             7458             7294           7260
# 422             251981           255269           262122         265128
# 1251            788280           790847           795251         798552
# 3177              8146             8460             8565           8569
# 16               47458            48516            49440          49948
# 650              22838            23084            23060          22985
# 2794             38275            38706            39084          39309
# 1269             39314            39247            39174          38520
# 2465              5379             5368             5371           5438
# 2598             30176            30217            30297          30464
# 618             196621           197570           199968         201081
# 3069             90764            92200            94165          96189
#
#        POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# index
# 2674             22931            23074            23408            23463
# 978               5541             5521             5560             5494
# 2048              5501             5800             5908             5977
# 186               7164             7052             7018             6860
# 422             271623           276164           277650           282201
# 1251            804063           806942           810846           815526
# 3177              8646             8641             8641             8582
# 16               50444            51141            50681            50657
# 650              22879            22710            22599            22492
# 2794             39731            39918            39757            40280
# 1269             38890            38993            38569            38254
# 2465              5559             5446             5484             5502
# 2598             30281            30031            30237            30123
# 618             203197           204630           206425           207942
# 3069             99018           100915           102266           103480
#
#        POPESTIMATE2015
# index
# 2674             23310
# 978               5420
# 2048              5975
# 186               6706
# 422             285959
# 1251            818117
# 3177              8611
# 16               50963
# 650              22260
# 2794             40317
# 1269             37973
# 2465              5404
# 2598             30140
# 618             209382
# 3069            104681

# %%
#Rename columns

population.rename(columns = {'CENSUS2010POP': '2010'})
# Out:
#        STATE  COUNTY   STNAME            CTYNAME  POPESTIMATE2006  \
# index
# 0          1       0  Alabama            Alabama          4628981
# 1          1       1  Alabama     Autauga County            51328
# 2          1       3  Alabama     Baldwin County           168121
# 3          1       5  Alabama     Barbour County            27861
# 4          1       7  Alabama        Bibb County            22099
# ...      ...     ...      ...                ...              ...
# 3186      56      37  Wyoming  Sweetwater County            39749
# 3187      56      39  Wyoming       Teton County            20014
# 3188      56      41  Wyoming       Uinta County            19709
# 3189      56      43  Wyoming    Washakie County             7979
# 3190      56      45  Wyoming      Weston County             6717
#
#        POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009     2010  \
# index
# 0              4672840          4718206          4757938  4779736
# 1                52405            53277            54135    54571
# 2               172404           175827           179406   182265
# 3                27757            27808            27657    27457
# 4                22438            22705            22941    22915
# ...                ...              ...              ...      ...
# 3186             41470            42358            44133    43806
# 3187             20472            20988            21232    21294
# 3188             20171            20613            21054    21118
# 3189              8169             8229             8423     8533
# 3190              7033             7133             7266     7208
#
#        POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# index
# 0              4799069          4815588          4830081          4841799
# 1                55227            54954            54727            54893
# 2               186558           190145           194885           199183
# 3                27341            27169            26937            26755
# 4                22745            22667            22521            22553
# ...                ...              ...              ...              ...
# 3186             43986            45002            45157            44948
# 3187             21414            21624            22315            22773
# 3188             20896            20996            20951            20822
# 3189              8449             8409             8413             8273
# 3190              7142             7077             7136             7138
#
#        POPESTIMATE2015
# index
# 0              4852347
# 1                54864
# 2               202939
# 3                26283
# 4                22566
# ...                ...
# 3186             44719
# 3187             23047
# 3188             20763
# 3189              8278
# 3190              7208
#
# [3191 rows x 14 columns]

# %%
# melt the population fields
melted_pop = pd.melt(population, ["STATE", "COUNTY", "STNAME", "CTYNAME"])

melted_pop.sample(14)
# Out:
#        STATE  COUNTY        STNAME            CTYNAME         variable   value
# 14343     29     143      Missouri  New Madrid County    CENSUS2010POP   18956
# 24173     35      19    New Mexico   Guadalupe County  POPESTIMATE2013    4531
# 29711     20     175        Kansas      Seward County  POPESTIMATE2015   23273
# 16996     21      61      Kentucky    Edmonson County  POPESTIMATE2011   12229
# 23767     28      11   Mississippi     Bolivar County  POPESTIMATE2013   33979
# 26492     20     119        Kansas       Meade County  POPESTIMATE2014    4357
# 27551     38       0  North Dakota       North Dakota  POPESTIMATE2014  737401
# 21817     48     213         Texas   Henderson County  POPESTIMATE2012   78992
# 30973     41      19        Oregon     Douglas County  POPESTIMATE2015  107164
# 26745     24      11      Maryland    Caroline County  POPESTIMATE2014   32532
# 15319     47     173     Tennessee       Union County    CENSUS2010POP   19109
# 22255     55      29     Wisconsin        Door County  POPESTIMATE2012   27536
# 17456     28     153   Mississippi       Wayne County  POPESTIMATE2011   20618
# 2103      39      51          Ohio      Fulton County  POPESTIMATE2006   42785
