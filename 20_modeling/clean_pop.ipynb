# %%
# Load packages
import pandas as pd
import numpy as np
import fastparquet

# %%
# Don't run this!!!
pop_data = pd.read_csv("/Users/preetkhowaja/Documents/MIDS Fall 2021/Practicing DS/Mid-sem Project/pop_data.csv", encoding='latin-1')
 # drop columns that aren't relevant
pop_data = pop_data.drop(columns = ["SUMLEV", "REGION", "DIVISION", "ESTIMATESBASE2000", "POPESTIMATE2000", 
"POPESTIMATE2001", "POPESTIMATE2002", "POPESTIMATE2003", "POPESTIMATE2004", "POPESTIMATE2005", "POPESTIMATE2010"])
pop_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/5b/sjkc4b8n0hs41zd03hxr66100000gn/T/ipykernel_26081/1206937730.py in <module>
#       1 # Don't run this!!!
# ----> 2 pop_data = pd.read_csv("/Users/preetkhowaja/Documents/MIDS Fall 2021/Practicing DS/Mid-sem Project/pop_data.csv", encoding='latin-1')
#       3  # drop columns that aren't relevant
#       4 pop_data = pop_data.drop(columns = ["SUMLEV", "REGION", "DIVISION", "ESTIMATESBASE2000", "POPESTIMATE2000",
#       5 "POPESTIMATE2001", "POPESTIMATE2002", "POPESTIMATE2003", "POPESTIMATE2004", "POPESTIMATE2005", "POPESTIMATE2010"])
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/preetkhowaja/Documents/MIDS Fall 2021/Practicing DS/Mid-sem Project/pop_data.csv'

# %%
# Don't run this!!!
# Reading in pop data after 2010
pop_data_2 = pd.read_csv("/Users/preetkhowaja/Documents/MIDS Fall 2021/Practicing DS/Mid-sem Project/pop_data_2.csv", encoding='latin-1')
pop_data_2 = pop_data_2[["STNAME", "CTYNAME", "POPESTIMATE2011", "POPESTIMATE2012", "POPESTIMATE2013", "POPESTIMATE2014", "POPESTIMATE2015"]]

pop_data_2.head()
# Out:
#     STNAME         CTYNAME  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0  Alabama         Alabama          4799069          4815588          4830081
# 1  Alabama  Autauga County            55227            54954            54727
# 2  Alabama  Baldwin County           186558           190145           194885
# 3  Alabama  Barbour County            27341            27169            26937
# 4  Alabama     Bibb County            22745            22667            22521
#
#    POPESTIMATE2014  POPESTIMATE2015
# 0          4841799          4852347
# 1            54893            54864
# 2           199183           202939
# 3            26755            26283
# 4            22553            22566

# %%
# Don't run this!!!
# Merging both datasets to have complete pop data

pop_merged = pd.merge(left = pop_data, right = pop_data_2)

# %%
# Don't run this!!!
# save file as parquet
pop_merged.to_parquet("/Users/preetkhowaja/Documents/MIDS Fall 2021/Practicing DS/pds2021-opioids-pds6/10_modified_data/pop_final.parquet", 
engine = 'fastparquet')

# %%
# RUN FROM HERE
# Read in parquet data
#population = pd.read_parquet("/Users/preetkhowaja/Documents/MIDS Fall 2021/Practicing DS/pds2021-opioids-pds6/10_modified_data/pop_final.parquet", engine = 'fastparquet')
population = pd.read_parquet("/Users/erikafox/Desktop/pds2021-opioids-pds6/10_modified_data/pop_final.parquet", engine = 'fastparquet')

# %%
population.sample(15)
# Out:
#        STATE  COUNTY          STNAME            CTYNAME  POPESTIMATE2006  \
# index
# 2361      45      11  South Carolina    Barnwell County            22886
# 1856      35      57      New Mexico    Torrance County            16728
# 3112      55      35       Wisconsin  Eau Claire County            95896
# 2633      48     137           Texas     Edwards County             1995
# 2046      38      45    North Dakota     LaMoure County             4357
# 2829      49      19            Utah       Grand County             8787
# 600       16      73           Idaho      Owyhee County            11114
# 730       18      37         Indiana      Dubois County            41589
# 844       19      79            Iowa    Hamilton County            16144
# 1766      31     171        Nebraska      Thomas County              659
# 950       20      91          Kansas     Johnson County           514813
# 1374      27      75       Minnesota        Lake County            10962
# 2340      42     117    Pennsylvania       Tioga County            41347
# 2494      47      51       Tennessee    Franklin County            40877
# 176        5     127        Arkansas       Scott County            11239
#
#        POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  CENSUS2010POP  \
# index
# 2361             22851            22761            22611          22621
# 1856             16559            16257            16414          16383
# 3112             96632            97176            98274          98736
# 2633              2062             2084             2012           2002
# 2046              4320             4218             4142           4139
# 2829              8838             8981             9034           9225
# 600              11255            11515            11547          11526
# 730              41728            41955            41897          41889
# 844              15987            15863            15739          15673
# 1766               667              661              655            647
# 950             523879           532175           539396         544179
# 1374             10938            10872            10872          10866
# 2340             41371            41609            41818          41981
# 2494             41151            41093            41141          41052
# 176              11287            11227            11097          11233
#
#        POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# index
# 2361             22460            22357            22210            22024
# 1856             16447            16155            15825            15666
# 3112             99938           100839           101734           101690
# 2633              1979             1990             1899             1904
# 2046              4095             4085             4101             4096
# 2829              9298             9358             9376             9481
# 600              11376            11409            11394            11288
# 730              42162            42083            42275            42297
# 844              15467            15321            15343            15217
# 1766               698              701              705              701
# 950             552907           559428           566351           572940
# 1374             10779            10792            10706            10602
# 2340             42242            42451            42211            41899
# 2494             40857            40688            41213            41288
# 176              11264            11033            10934            10686
#
#        POPESTIMATE2015
# index
# 2361             21781
# 1856             15596
# 3112            102080
# 2633              1910
# 2046              4136
# 2829              9551
# 600              11288
# 730              42317
# 844              15218
# 1766               693
# 950             579684
# 1374             10541
# 2340             41519
# 2494             41343
# 176              10561

# %%
#Rename columns
for col in population.columns:
    if "POPESTIMATE" in col:
        x= col[-4:]
        print(x)
        population.rename(columns={col:x},inplace=True)
population.rename(columns={"CENSUS2010POP":"2010"},inplace=True)
population
# Out:
#        STATE  COUNTY   STNAME            CTYNAME     2006     2007     2008  \
# index
# 0          1       0  Alabama            Alabama  4628981  4672840  4718206
# 1          1       1  Alabama     Autauga County    51328    52405    53277
# 2          1       3  Alabama     Baldwin County   168121   172404   175827
# 3          1       5  Alabama     Barbour County    27861    27757    27808
# 4          1       7  Alabama        Bibb County    22099    22438    22705
# ...      ...     ...      ...                ...      ...      ...      ...
# 3186      56      37  Wyoming  Sweetwater County    39749    41470    42358
# 3187      56      39  Wyoming       Teton County    20014    20472    20988
# 3188      56      41  Wyoming       Uinta County    19709    20171    20613
# 3189      56      43  Wyoming    Washakie County     7979     8169     8229
# 3190      56      45  Wyoming      Weston County     6717     7033     7133
#
#           2009     2010     2011     2012     2013     2014     2015
# index
# 0      4757938  4779736  4799069  4815588  4830081  4841799  4852347
# 1        54135    54571    55227    54954    54727    54893    54864
# 2       179406   182265   186558   190145   194885   199183   202939
# 3        27657    27457    27341    27169    26937    26755    26283
# 4        22941    22915    22745    22667    22521    22553    22566
# ...        ...      ...      ...      ...      ...      ...      ...
# 3186     44133    43806    43986    45002    45157    44948    44719
# 3187     21232    21294    21414    21624    22315    22773    23047
# 3188     21054    21118    20896    20996    20951    20822    20763
# 3189      8423     8533     8449     8409     8413     8273     8278
# 3190      7266     7208     7142     7077     7136     7138     7208
#
# [3191 rows x 14 columns]

# %%
# melt the population fields
melted_pop = pd.melt(population, ["STATE", "COUNTY", "STNAME", "CTYNAME"])

melted_pop.sample(14)
# Out:
#        STATE  COUNTY        STNAME            CTYNAME         variable   value
# 14343     29     143      Missouri  New Madrid County    CENSUS2010POP   18956
# 24173     35      19    New Mexico   Guadalupe County  POPESTIMATE2013    4531
# 29711     20     175        Kansas      Seward County  POPESTIMATE2015   23273
# 16996     21      61      Kentucky    Edmonson County  POPESTIMATE2011   12229
# 23767     28      11   Mississippi     Bolivar County  POPESTIMATE2013   33979
# 26492     20     119        Kansas       Meade County  POPESTIMATE2014    4357
# 27551     38       0  North Dakota       North Dakota  POPESTIMATE2014  737401
# 21817     48     213         Texas   Henderson County  POPESTIMATE2012   78992
# 30973     41      19        Oregon     Douglas County  POPESTIMATE2015  107164
# 26745     24      11      Maryland    Caroline County  POPESTIMATE2014   32532
# 15319     47     173     Tennessee       Union County    CENSUS2010POP   19109
# 22255     55      29     Wisconsin        Door County  POPESTIMATE2012   27536
# 17456     28     153   Mississippi       Wayne County  POPESTIMATE2011   20618
# 2103      39      51          Ohio      Fulton County  POPESTIMATE2006   42785
